# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt

#Import cranial database 
df = pd.read_csv('../../datasources/fdb/cranial.csv')
#This shuffles the rows.
df = df.sample(frac=1)

#Drop categorical data. We'll focus only on measurement data.
del df['DB']
del df['Item']
del df['ID']
del df['ContNum']
del df['FDN']
del df['Pop']
del df['PopSex']
del df['Ethnicity'] #Probably really important.
del df['BirthYear']
del df['Age'] #Probably really important.
del df['Comments']

#This col is basically empty and disturbs standardization.
del df["MOW"]

rows, cols = df.shape 
print("Starting with", rows, "individuals and", cols, "features.")
# Out:
# Starting with 5342 individuals and 110 features.

# %%
#Consider our target col, Sex.
print("Unique entries.")
df['Sex'].value_counts(dropna=False)
# Out:
# Unique entries.
# M      3187
# F      2095
# N        58
# NaN       2
# Name: Sex, dtype: int64

# %%
#Clean N and Nan entries
df = df[~(df.Sex.str.contains("N") == True)]
df = df.dropna(subset = ['Sex'])

#Move from object to float.
df['Sex'] = df['Sex'].map({'M':1.0, 'F':0.})
df.describe()
# Out:
# /usr/local/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                Sex          GOL          NOL          BNL          BBH  \
# count  5282.000000  5200.000000  4396.000000  5177.000000  5182.000000
# mean      0.603370   180.397500   177.689945   100.143906   133.846584
# std       0.489244     8.838111     8.238570     5.764435     7.336864
# min       0.000000   131.000000   150.000000    79.000000   107.000000
# 25%       0.000000          NaN          NaN          NaN          NaN
# 50%       1.000000          NaN          NaN          NaN          NaN
# 75%       1.000000          NaN          NaN          NaN          NaN
# max       1.000000   211.000000   207.000000   120.000000   157.000000
#
#                XCB          XFB          WFB          ZYB          AUB  \
# count  5196.000000  4395.000000  2622.000000  5096.000000  5106.000000
# mean    137.568129   114.752673    94.898932   129.449372   120.855660
# std       6.811824     6.477442     4.952665     7.313785     6.763771
# min     116.000000    93.000000    79.000000    90.000000    98.000000
# 25%            NaN          NaN          NaN          NaN          NaN
# 50%            NaN          NaN          NaN          NaN          NaN
# 75%            NaN          NaN          NaN          NaN          NaN
# max     167.000000   145.000000   119.000000   158.000000   154.000000
#
#           ...             MLN         MAN        BABR        BANA        BAPR  \
# count     ...      519.000000  518.000000  636.000000  607.000000  574.000000
# mean      ...       77.046243  124.990347  136.886792  101.494234   97.031359
# std       ...        7.211489    7.455211    6.889893    5.523686    6.481473
# min       ...       54.000000   90.000000   84.000000   85.000000   73.000000
# 25%       ...             NaN         NaN         NaN         NaN         NaN
# 50%       ...             NaN         NaN         NaN         NaN         NaN
# 75%       ...             NaN         NaN         NaN         NaN         NaN
# max       ...      120.000000  147.000000  156.000000  130.000000  116.000000
#
#               UFHT         UFBR        ORBR        BIOB        INTB
# count  2115.000000  1605.000000  453.000000  604.000000  413.000000
# mean     70.201891   103.535826   41.008830   96.253311   20.552058
# std       4.934519     4.827782    2.493338    4.400408    3.388348
# min      47.000000    87.000000   34.000000   81.000000    0.000000
# 25%            NaN          NaN         NaN         NaN         NaN
# 50%            NaN          NaN         NaN         NaN         NaN
# 75%            NaN          NaN         NaN         NaN         NaN
# max      91.000000   122.000000   51.000000  112.000000   29.000000
#
# [8 rows x 110 columns]

# %%
#Split into data and labels.
X = df.drop(['Sex'], axis=1)
y = df[['Sex']]

# %%
#Split train test
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01)

# %%
X_train.isnull().sum().sum()
# Out:
# 201219

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5229, 109), (53, 109), (5229, 1), (53, 1))

# %%
#Standardize df. Can't use scikit's scale because it doesn't like Nan.
X_train_mean = X_train.mean()
X_train_std = X_train.std()
X_train = (X_train - X_train_mean) / (X_train_std)
#Intentionally using train stats for test set.
X_test = ( X_test - X_train_mean) / (X_train_std)
X_train.describe()
# Out:
# /usr/local/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                 GOL           NOL           BNL           BBH           XCB  \
# count  5.148000e+03  4.349000e+03  5.125000e+03  5.130000e+03  5.144000e+03
# mean   7.591269e-17 -4.987196e-16 -2.218280e-17  9.834022e-16 -1.217619e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -5.582534e+00 -3.357156e+00 -3.670704e+00 -3.654984e+00 -3.163812e+00
# 25%             NaN           NaN           NaN           NaN           NaN
# 50%             NaN           NaN           NaN           NaN           NaN
# 75%             NaN           NaN           NaN           NaN           NaN
# max    3.457765e+00  3.552178e+00  3.449335e+00  3.152281e+00  4.313258e+00
#
#                 XFB           WFB           ZYB           AUB           ASB  \
# count  4.347000e+03  2.595000e+03  5.046000e+03  5.054000e+03  4.349000e+03
# mean  -8.140103e-16  1.505967e-16 -1.396866e-15 -8.533824e-16 -1.744089e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.359802e+00 -3.205032e+00 -3.355656e+00 -3.376289e+00 -3.349440e+00
# 25%             NaN           NaN           NaN           NaN           NaN
# 50%             NaN           NaN           NaN           NaN           NaN
# 75%             NaN           NaN           NaN           NaN           NaN
# max    4.669028e+00  4.862341e+00  3.913220e+00  4.892685e+00  3.534176e+00
#
#            ...                MLN           MAN          BABR          BANA  \
# count      ...       5.120000e+02  5.110000e+02  6.330000e+02  6.040000e+02
# mean       ...      -5.204170e-18  2.077051e-16 -9.204503e-16  1.195512e-15
# std        ...       1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min        ...      -3.186018e+00 -4.703000e+00 -7.670821e+00 -2.982493e+00
# 25%        ...                NaN           NaN           NaN           NaN
# 50%        ...                NaN           NaN           NaN           NaN
# 75%        ...                NaN           NaN           NaN           NaN
# max        ...       5.961906e+00  2.944199e+00  2.775450e+00  5.160567e+00
#
#                BAPR          UFHT          UFBR          ORBR          BIOB  \
# count  5.710000e+02  2.094000e+03  1.584000e+03  4.500000e+02  6.010000e+02
# mean  -9.768407e-16 -3.562893e-16 -9.420074e-16 -2.822434e-16  1.075863e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.697707e+00 -4.697471e+00 -3.430601e+00 -2.800909e+00 -3.459169e+00
# 25%             NaN           NaN           NaN           NaN           NaN
# 50%             NaN           NaN           NaN           NaN           NaN
# 75%             NaN           NaN           NaN           NaN           NaN
# max    2.922038e+00  4.207823e+00  3.830318e+00  3.996982e+00  3.575078e+00
#
#                INTB
# count  4.110000e+02
# mean  -2.895764e-16
# std    1.000000e+00
# min   -6.055747e+00
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max    2.493163e+00
#
# [8 rows x 109 columns]

# %%
#The imputer. I haven't looked closely at this algo. Try other variations.
from fancyimpute import KNN, SoftImpute
# X_train_filled = pd.DataFrame(KNN(k=3).complete(X_train))
# X_test_filled = pd.DataFrame(KNN(k=3).complete(X_test))
X_train_filled = SoftImpute().complete(X_train)
X_test_filled = SoftImpute().complete(X_test)
# Out:
# [SoftImpute] Max Singular Value of X_init = 279.713738
# [SoftImpute] Iter 1: observed MAE=0.062063 rank=106
# [SoftImpute] Iter 2: observed MAE=0.062472 rank=103
# [SoftImpute] Iter 3: observed MAE=0.062746 rank=102
# [SoftImpute] Iter 4: observed MAE=0.062965 rank=101
# [SoftImpute] Iter 5: observed MAE=0.063128 rank=101
# [SoftImpute] Iter 6: observed MAE=0.063278 rank=101
# [SoftImpute] Iter 7: observed MAE=0.063387 rank=100
# [SoftImpute] Iter 8: observed MAE=0.063480 rank=99
# [SoftImpute] Iter 9: observed MAE=0.063554 rank=99
# [SoftImpute] Iter 10: observed MAE=0.063617 rank=99
# [SoftImpute] Iter 11: observed MAE=0.063671 rank=99
# [SoftImpute] Iter 12: observed MAE=0.063716 rank=99
# [SoftImpute] Iter 13: observed MAE=0.063746 rank=97
# [SoftImpute] Iter 14: observed MAE=0.063762 rank=97
# [SoftImpute] Iter 15: observed MAE=0.063779 rank=97
# [SoftImpute] Iter 16: observed MAE=0.063794 rank=97
# [SoftImpute] Iter 17: observed MAE=0.063808 rank=97
# [SoftImpute] Iter 18: observed MAE=0.063819 rank=97
# [SoftImpute] Iter 19: observed MAE=0.063823 rank=96
# [SoftImpute] Iter 20: observed MAE=0.063826 rank=96
# [SoftImpute] Iter 21: observed MAE=0.063828 rank=96
# [SoftImpute] Iter 22: observed MAE=0.063830 rank=96
# [SoftImpute] Iter 23: observed MAE=0.063832 rank=96
# [SoftImpute] Iter 24: observed MAE=0.063833 rank=96
# [SoftImpute] Iter 25: observed MAE=0.063835 rank=96
# [SoftImpute] Iter 26: observed MAE=0.063836 rank=96
# [SoftImpute] Iter 27: observed MAE=0.063837 rank=96
# [SoftImpute] Iter 28: observed MAE=0.063838 rank=96
# [SoftImpute] Iter 29: observed MAE=0.063838 rank=96
# [SoftImpute] Iter 30: observed MAE=0.063835 rank=95
# [SoftImpute] Iter 31: observed MAE=0.063834 rank=95
# [SoftImpute] Iter 32: observed MAE=0.063828 rank=94
# [SoftImpute] Iter 33: observed MAE=0.063823 rank=94
# [SoftImpute] Iter 34: observed MAE=0.063819 rank=94
# [SoftImpute] Iter 35: observed MAE=0.063815 rank=94
# [SoftImpute] Iter 36: observed MAE=0.063812 rank=94
# [SoftImpute] Iter 37: observed MAE=0.063809 rank=94
# [SoftImpute] Iter 38: observed MAE=0.063806 rank=94
# [SoftImpute] Iter 39: observed MAE=0.063804 rank=94
# [SoftImpute] Iter 40: observed MAE=0.063801 rank=94
# [SoftImpute] Iter 41: observed MAE=0.063799 rank=94
# [SoftImpute] Iter 42: observed MAE=0.063797 rank=94
# [SoftImpute] Iter 43: observed MAE=0.063795 rank=94
# [SoftImpute] Iter 44: observed MAE=0.063793 rank=94
# [SoftImpute] Iter 45: observed MAE=0.063792 rank=94
# [SoftImpute] Iter 46: observed MAE=0.063790 rank=94
# [SoftImpute] Iter 47: observed MAE=0.063789 rank=94
# [SoftImpute] Iter 48: observed MAE=0.063787 rank=94
# [SoftImpute] Iter 49: observed MAE=0.063786 rank=94
# [SoftImpute] Iter 50: observed MAE=0.063785 rank=94
# [SoftImpute] Iter 51: observed MAE=0.063783 rank=94
# [SoftImpute] Iter 52: observed MAE=0.063782 rank=94
# [SoftImpute] Iter 53: observed MAE=0.063781 rank=94
# [SoftImpute] Iter 54: observed MAE=0.063780 rank=94
# [SoftImpute] Iter 55: observed MAE=0.063779 rank=94
# [SoftImpute] Iter 56: observed MAE=0.063778 rank=94
# [SoftImpute] Iter 57: observed MAE=0.063777 rank=94
# [SoftImpute] Iter 58: observed MAE=0.063776 rank=94
# [SoftImpute] Iter 59: observed MAE=0.063776 rank=94
# [SoftImpute] Iter 60: observed MAE=0.063775 rank=94
# [SoftImpute] Iter 61: observed MAE=0.063774 rank=94
# [SoftImpute] Iter 62: observed MAE=0.063773 rank=94
# [SoftImpute] Iter 63: observed MAE=0.063773 rank=94
# [SoftImpute] Iter 64: observed MAE=0.063772 rank=94
# [SoftImpute] Iter 65: observed MAE=0.063771 rank=94
# [SoftImpute] Iter 66: observed MAE=0.063771 rank=94
# [SoftImpute] Iter 67: observed MAE=0.063770 rank=94
# [SoftImpute] Iter 68: observed MAE=0.063769 rank=94
# [SoftImpute] Iter 69: observed MAE=0.063769 rank=94
# [SoftImpute] Iter 70: observed MAE=0.063768 rank=94
# [SoftImpute] Iter 71: observed MAE=0.063768 rank=94
# [SoftImpute] Iter 72: observed MAE=0.063767 rank=94
# [SoftImpute] Iter 73: observed MAE=0.063767 rank=94
# [SoftImpute] Iter 74: observed MAE=0.063767 rank=94
# [SoftImpute] Iter 75: observed MAE=0.063766 rank=94
# [SoftImpute] Iter 76: observed MAE=0.063766 rank=94
# [SoftImpute] Iter 77: observed MAE=0.063765 rank=94
# [SoftImpute] Iter 78: observed MAE=0.063765 rank=94
# [SoftImpute] Iter 79: observed MAE=0.063765 rank=94
# [SoftImpute] Iter 80: observed MAE=0.063764 rank=94
# [SoftImpute] Iter 81: observed MAE=0.063764 rank=94
# [SoftImpute] Iter 82: observed MAE=0.063764 rank=94
# [SoftImpute] Iter 83: observed MAE=0.063763 rank=94
# [SoftImpute] Iter 84: observed MAE=0.063763 rank=94
# [SoftImpute] Iter 85: observed MAE=0.063763 rank=94
# [SoftImpute] Iter 86: observed MAE=0.063762 rank=94
# [SoftImpute] Iter 87: observed MAE=0.063762 rank=94
# [SoftImpute] Iter 88: observed MAE=0.063762 rank=94
# [SoftImpute] Iter 89: observed MAE=0.063762 rank=94
# [SoftImpute] Iter 90: observed MAE=0.063761 rank=94
# [SoftImpute] Iter 91: observed MAE=0.063761 rank=94
# [SoftImpute] Iter 92: observed MAE=0.063761 rank=94
# [SoftImpute] Iter 93: observed MAE=0.063761 rank=94
# [SoftImpute] Iter 94: observed MAE=0.063761 rank=94
# [SoftImpute] Iter 95: observed MAE=0.063760 rank=94
# [SoftImpute] Iter 96: observed MAE=0.063760 rank=94
# [SoftImpute] Iter 97: observed MAE=0.063760 rank=94
# [SoftImpute] Iter 98: observed MAE=0.063760 rank=94
# [SoftImpute] Iter 99: observed MAE=0.063760 rank=94
# [SoftImpute] Iter 100: observed MAE=0.063759 rank=94
# [SoftImpute] Stopped after iteration 100 for lambda=5.594275
# [SoftImpute] Max Singular Value of X_init = 27.872518
# [SoftImpute] Iter 1: observed MAE=0.047472 rank=53
# [SoftImpute] Iter 2: observed MAE=0.047810 rank=53
# [SoftImpute] Iter 3: observed MAE=0.048090 rank=53
# [SoftImpute] Iter 4: observed MAE=0.048320 rank=53
# [SoftImpute] Iter 5: observed MAE=0.048468 rank=52
# [SoftImpute] Iter 6: observed MAE=0.048525 rank=52
# [SoftImpute] Iter 7: observed MAE=0.048595 rank=52
# [SoftImpute] Iter 8: observed MAE=0.048635 rank=51
# [SoftImpute] Iter 9: observed MAE=0.048670 rank=51
# [SoftImpute] Iter 10: observed MAE=0.048704 rank=51
# [SoftImpute] Iter 11: observed MAE=0.048741 rank=51
# [SoftImpute] Iter 12: observed MAE=0.048778 rank=51
# [SoftImpute] Iter 13: observed MAE=0.048784 rank=50
# [SoftImpute] Iter 14: observed MAE=0.048780 rank=50
# [SoftImpute] Iter 15: observed MAE=0.048781 rank=50
# [SoftImpute] Iter 16: observed MAE=0.048786 rank=50
# [SoftImpute] Iter 17: observed MAE=0.048793 rank=50
# [SoftImpute] Iter 18: observed MAE=0.048796 rank=49
# [SoftImpute] Iter 19: observed MAE=0.048783 rank=49
# [SoftImpute] Iter 20: observed MAE=0.048773 rank=49
# [SoftImpute] Iter 21: observed MAE=0.048767 rank=49
# [SoftImpute] Iter 22: observed MAE=0.048762 rank=49
# [SoftImpute] Iter 23: observed MAE=0.048759 rank=49
# [SoftImpute] Iter 24: observed MAE=0.048736 rank=48
# [SoftImpute] Iter 25: observed MAE=0.048718 rank=48
# [SoftImpute] Iter 26: observed MAE=0.048705 rank=48
# [SoftImpute] Iter 27: observed MAE=0.048696 rank=48
# [SoftImpute] Iter 28: observed MAE=0.048691 rank=48
# [SoftImpute] Iter 29: observed MAE=0.048687 rank=48
# [SoftImpute] Iter 30: observed MAE=0.048685 rank=48
# [SoftImpute] Iter 31: observed MAE=0.048683 rank=48
# [SoftImpute] Iter 32: observed MAE=0.048682 rank=48
# [SoftImpute] Iter 33: observed MAE=0.048681 rank=48
# [SoftImpute] Iter 34: observed MAE=0.048681 rank=48
# [SoftImpute] Iter 35: observed MAE=0.048682 rank=48
# [SoftImpute] Iter 36: observed MAE=0.048682 rank=48
# [SoftImpute] Iter 37: observed MAE=0.048683 rank=48
# [SoftImpute] Iter 38: observed MAE=0.048685 rank=48
# [SoftImpute] Iter 39: observed MAE=0.048686 rank=48
# [SoftImpute] Iter 40: observed MAE=0.048687 rank=48
# [SoftImpute] Iter 41: observed MAE=0.048689 rank=48
# [SoftImpute] Iter 42: observed MAE=0.048690 rank=48
# [SoftImpute] Iter 43: observed MAE=0.048691 rank=48
# [SoftImpute] Iter 44: observed MAE=0.048676 rank=47
# [SoftImpute] Iter 45: observed MAE=0.048665 rank=47
# [SoftImpute] Iter 46: observed MAE=0.048657 rank=47
# [SoftImpute] Iter 47: observed MAE=0.048651 rank=47
# [SoftImpute] Iter 48: observed MAE=0.048647 rank=47
# [SoftImpute] Iter 49: observed MAE=0.048643 rank=47
# [SoftImpute] Iter 50: observed MAE=0.048640 rank=47
# [SoftImpute] Iter 51: observed MAE=0.048638 rank=47
# [SoftImpute] Iter 52: observed MAE=0.048636 rank=47
# [SoftImpute] Iter 53: observed MAE=0.048634 rank=47
# [SoftImpute] Iter 54: observed MAE=0.048633 rank=47
# [SoftImpute] Iter 55: observed MAE=0.048631 rank=47
# [SoftImpute] Iter 56: observed MAE=0.048630 rank=47
# [SoftImpute] Iter 57: observed MAE=0.048629 rank=47
# [SoftImpute] Iter 58: observed MAE=0.048628 rank=47
# [SoftImpute] Iter 59: observed MAE=0.048627 rank=47
# [SoftImpute] Iter 60: observed MAE=0.048626 rank=47
# [SoftImpute] Iter 61: observed MAE=0.048625 rank=47
# [SoftImpute] Iter 62: observed MAE=0.048624 rank=47
# [SoftImpute] Iter 63: observed MAE=0.048623 rank=47
# [SoftImpute] Iter 64: observed MAE=0.048623 rank=47
# [SoftImpute] Iter 65: observed MAE=0.048622 rank=47
# [SoftImpute] Iter 66: observed MAE=0.048621 rank=47
# [SoftImpute] Iter 67: observed MAE=0.048621 rank=47
# [SoftImpute] Iter 68: observed MAE=0.048620 rank=47
# [SoftImpute] Iter 69: observed MAE=0.048620 rank=47
# [SoftImpute] Iter 70: observed MAE=0.048619 rank=47
# [SoftImpute] Iter 71: observed MAE=0.048619 rank=47
# [SoftImpute] Iter 72: observed MAE=0.048619 rank=47
# [SoftImpute] Iter 73: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 74: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 75: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 76: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 77: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 78: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 79: observed MAE=0.048617 rank=47
# [SoftImpute] Iter 80: observed MAE=0.048617 rank=47
# [SoftImpute] Iter 81: observed MAE=0.048617 rank=47
# [SoftImpute] Iter 82: observed MAE=0.048617 rank=47
# [SoftImpute] Iter 83: observed MAE=0.048617 rank=47
# [SoftImpute] Iter 84: observed MAE=0.048617 rank=47
# [SoftImpute] Iter 85: observed MAE=0.048617 rank=47
# [SoftImpute] Iter 86: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 87: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 88: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 89: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 90: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 91: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 92: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 93: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 94: observed MAE=0.048618 rank=47
# [SoftImpute] Iter 95: observed MAE=0.048619 rank=47
# [SoftImpute] Iter 96: observed MAE=0.048619 rank=47
# [SoftImpute] Iter 97: observed MAE=0.048619 rank=47
# [SoftImpute] Iter 98: observed MAE=0.048619 rank=47
# [SoftImpute] Iter 99: observed MAE=0.048619 rank=47
# [SoftImpute] Iter 100: observed MAE=0.048619 rank=47
# [SoftImpute] Stopped after iteration 100 for lambda=0.557450

# %%
#Num zero entries
(X_train_filled == 0).astype(int).sum().sum(),(X_test_filled == 0).astype(int).sum().sum()
# Out:
# (1853, 0)

# %%
#Impute zeros with mean. Could do this better.
#Think this introduces an improbable bug when the train set
#Has representation in a col that the test set doesn't or 
#Vice versa. Ignoring it for now. 
from sklearn.preprocessing import Imputer
imp = Imputer(missing_values=0, strategy='mean', axis=0)
X_train_filled = pd.DataFrame(imp.fit_transform(X_train_filled))
X_train_filled = pd.DataFrame(imp.transform(X_train_filled))
X_test_filled = pd.DataFrame(imp.fit_transform(X_test_filled))

# %%
#No zero values
(X_train_filled == 0).astype(int).sum().sum(), (X_test_filled == 0).astype(int).sum().sum()
# Out:
# (0, 0)

# %%
#Notice that the training (and testing) set is no longer standardized
X_train_filled.describe()
# Out:
#                0            1            2            3            4    \
# count  5229.000000  5229.000000  5229.000000  5229.000000  5229.000000
# mean      0.002446     0.025758     0.002377     0.002173     0.000909
# std       0.994437     0.975632     0.994933     0.993018     0.992990
# min      -5.582534    -3.357156    -3.670704    -3.654984    -3.163812
# 25%      -0.723373    -0.622953    -0.718493    -0.659787    -0.671455
# 50%      -0.045351     0.036903    -0.023855     0.020939    -0.085019
# 75%       0.745675     0.644798     0.670783     0.701666     0.648028
# max       3.457765     3.552178     5.606616     3.152281     4.313258
#
#                5            6            7            8            9    \
# count  5229.000000  5229.000000  5229.000000  5229.000000  5229.000000
# mean      0.010368    -0.034736    -0.002499    -0.002054     0.011452
# std       0.938159     0.800749     0.989001     0.988037     0.934575
# min      -3.359802    -3.205032    -3.355656    -3.376289    -3.349440
# 25%      -0.580592    -0.535161    -0.749833    -0.718405    -0.563215
# 50%       0.037011    -0.048235    -0.064090     0.019896     0.011452
# 75%       0.613739     0.425286     0.621653     0.610537     0.584055
# max       4.669028     4.862341     3.913220     4.892685     3.534176
#
#           ...               99           100          101          102  \
# count     ...       5229.000000  5229.000000  5229.000000  5229.000000
# mean      ...         -0.005339    -0.005193    -0.011222    -0.002438
# std       ...          0.403877     0.346891     0.604945     0.627776
# min       ...         -3.186018    -4.703000    -7.670821    -2.982493
# 25%       ...         -0.196726    -0.111094    -0.395434    -0.418413
# 50%       ...         -0.005339    -0.005193    -0.011222    -0.017277
# 75%       ...          0.178733     0.102175     0.379351     0.399659
# max       ...          5.961906     2.944199     2.775450     5.160567
#
#                103          104          105          106          107  \
# count  5229.000000  5229.000000  5229.000000  5229.000000  5229.000000
# mean     -0.003152    -0.033384    -0.002273     0.005356    -0.002538
# std       0.654798     0.897506     0.812758     0.455549     0.643631
# min      -3.697707    -4.697471    -3.430601    -2.800909    -3.459169
# 25%      -0.429821    -0.609212    -0.526233    -0.263521    -0.422802
# 50%      -0.003152    -0.042431     0.000465    -0.001777    -0.016299
# 75%       0.408231     0.564748     0.511041     0.260416     0.398322
# max       2.922038     4.207823     3.830318     3.996982     3.575078
#
#                108
# count  5229.000000
# mean      0.001519
# std       0.376582
# min      -6.055747
# 25%      -0.175777
# 50%       0.001519
# 75%       0.173197
# max       2.493163
#
# [8 rows x 109 columns]

# %%
#Should we standardize again?
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(X_train_filled)
X_train_filled = pd.DataFrame(scaler.transform(X_train_filled))
#Uses test stats
X_test_filled = pd.DataFrame(scaler.transform(X_test_filled))

# %%
#Save to disk
X_train_filled.to_csv("data/X_train_preproc.csv", index=False)
#Ravel strips col name and reindexes
pd.DataFrame(np.ravel(y_train)).to_csv("data/y_train_preproc.csv", index=False)

X_test_filled.to_csv("data/X_test_preproc.csv", index=False)
pd.DataFrame(np.ravel(y_test)).to_csv("data/y_test_preproc.csv", index=False)
