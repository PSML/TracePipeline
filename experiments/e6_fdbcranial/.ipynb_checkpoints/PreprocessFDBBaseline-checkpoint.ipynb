# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt
from math import floor
from sklearn.preprocessing import PolynomialFeatures


#Import cranial database 
df = pd.read_csv('../../datasources/fdb/cranial.csv')

#Drop categorical data. We'll focus on measurement data.
del df['DB']
del df['Item']
del df['ID']
del df['ContNum']
del df['FDN']
del df['Pop']
del df['PopSex']
del df['Ethnicity'] #Probably really important.
del df['BirthYear']
del df['Age'] #Probably really important.
del df['Comments']

rows, cols = df.shape 
print("Starting with", rows, "individuals and", cols, "features.")
# Out:
# Starting with 5342 individuals and 111 features.

# %%
#Consider our target col, Sex.
print("Unique entries.")
df['Sex'].value_counts(dropna=False)
# Out:
# Unique entries.
# M      3187
# F      2095
# N        58
# NaN       2
# Name: Sex, dtype: int64

# %%
#Clean N and Nan entries
df = df[~(df.Sex.str.contains("N") == True)]
df = df.dropna(subset = ['Sex'])

df['Sex'].value_counts(dropna=False)
# Out:
# M    3187
# F    2095
# Name: Sex, dtype: int64

# %%
#Move from object to float
df['Sex'] = df['Sex'].map({'M':1, 'F':0})

# %%
#Shuffle rows of df
df = df.iloc[np.random.permutation(len(df))]

#Split into train and test sets
p=0.8
split_pt = floor(len(df)*p)
train, test = df.iloc[0:split_pt], df[split_pt:]

# %%
#Use train mean and std on test data.
tr_mean = train.mean()
tr_std  = train.std()
train = ( train - tr_mean ) / tr_std
test  = ( test - tr_mean ) / tr_std

#Clean this up.
train['Sex'] = train['Sex'].apply(np.sign)
test['Sex']  = test['Sex'].apply(np.sign)
train['Sex'] = ( train['Sex'] + 1 ) / 2
test['Sex'] = ( test['Sex'] + 1 ) / 2

# %%
train.describe()
# Out:
# /usr/local/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                Sex           GOL           NOL           BNL           BBH  \
# count  4225.000000  4.167000e+03  3.518000e+03  4.145000e+03  4.152000e+03
# mean      0.604260  6.914449e-16  1.154278e-15  7.885396e-17 -1.668543e-15
# std       0.489067  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min       0.000000 -5.572678e+00 -3.353755e+00 -3.666009e+00 -3.546959e+00
# 25%       0.000000           NaN           NaN           NaN           NaN
# 50%       1.000000           NaN           NaN           NaN           NaN
# 75%       1.000000           NaN           NaN           NaN           NaN
# max       1.000000  3.450271e+00  3.549429e+00  3.440007e+00  3.156572e+00
#
#                 XCB           XFB           WFB           ZYB           AUB  \
# count  4.163000e+03  3.516000e+03  2.108000e+03  4.091000e+03  4.098000e+03
# mean   1.117104e-15  1.057933e-15  3.286429e-16  1.657817e-15 -1.047262e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.163140e+00 -3.217278e+00 -3.220198e+00 -5.419327e+00 -3.388567e+00
# 25%             NaN           NaN           NaN           NaN           NaN
# 50%             NaN           NaN           NaN           NaN           NaN
# 75%             NaN           NaN           NaN           NaN           NaN
# max    4.295415e+00  4.632471e+00  4.860965e+00  3.921911e+00  4.906919e+00
#
#       ...            MAN          BABR          BANA          BAPR  \
# count ...   4.270000e+02  5.230000e+02  4.960000e+02  4.720000e+02
# mean  ...  -8.278572e-16  1.518225e-15 -1.683241e-16  2.276898e-16
# std   ...   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   ...  -4.647896e+00 -7.548960e+00 -2.765375e+00 -2.971446e+00
# 25%   ...            NaN           NaN           NaN           NaN
# 50%   ...            NaN           NaN           NaN           NaN
# 75%   ...            NaN           NaN           NaN           NaN
# max   ...   2.963808e+00  2.459276e+00  5.038031e+00  2.958222e+00
#
#                UFHT          UFBR          ORBR          BIOB          INTB  \
# count  1.710000e+03  1.310000e+03  3.690000e+02  4.940000e+02  3.420000e+02
# mean   2.389252e-17 -7.024068e-16  3.441992e-16  3.739699e-16  1.194626e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -4.731309e+00 -3.449389e+00 -2.453465e+00 -3.478257e+00 -5.755833e+00
# 25%             NaN           NaN           NaN           NaN           NaN
# 50%             NaN           NaN           NaN           NaN           NaN
# 75%             NaN           NaN           NaN           NaN           NaN
# max    4.204921e+00  3.835143e+00  3.655365e+00  3.629566e+00  2.392376e+00
#
#        MOW
# count  0.0
# mean   NaN
# std    NaN
# min    NaN
# 25%    NaN
# 50%    NaN
# 75%    NaN
# max    NaN
#
# [8 rows x 111 columns]

# %%
test.describe()
# Out:
# /usr/local/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                Sex          GOL         NOL          BNL          BBH  \
# count  1057.000000  1033.000000  878.000000  1032.000000  1030.000000
# mean      0.599811    -0.006488   -0.001340    -0.007029    -0.055199
# std       0.490168     0.984365    0.989304     0.995826     1.017933
# min       0.000000    -2.865793   -2.627104    -2.799422    -3.683766
# 25%       0.000000          NaN         NaN          NaN          NaN
# 50%       1.000000          NaN         NaN          NaN          NaN
# 75%       1.000000          NaN         NaN          NaN          NaN
# max       1.000000     2.886337    2.822778     2.746737     2.882959
#
#                XCB         XFB         WFB          ZYB          AUB ...   \
# count  1033.000000  879.000000  514.000000  1005.000000  1008.000000 ...
# mean     -0.044685   -0.115481   -0.041581    -0.000616    -0.014558 ...
# std       0.980415    0.979968    1.003249     1.024129     1.010215 ...
# min      -2.578155   -3.371195   -2.816140    -3.358760    -3.388567 ...
# 25%            NaN         NaN         NaN          NaN          NaN ...
# 50%            NaN         NaN         NaN          NaN          NaN ...
# 75%            NaN         NaN         NaN          NaN          NaN ...
# max       4.295415    2.939388    3.446762     3.097684     3.721850 ...
#
#              MAN        BABR        BANA        BAPR        UFHT        UFBR  \
# count  91.000000  113.000000  111.000000  102.000000  405.000000  295.000000
# mean    0.140419    0.070458   -0.095536   -0.009672   -0.099714   -0.042415
# std     0.971477    0.914824    0.882820    1.067636    1.008600    1.026874
# min    -2.911893   -2.544842   -2.942725   -3.751666   -3.106539   -2.408741
# 25%          NaN         NaN         NaN         NaN         NaN         NaN
# 50%          NaN         NaN         NaN         NaN         NaN         NaN
# 75%          NaN         NaN         NaN         NaN         NaN         NaN
# max     2.563192    2.745226    2.377779    2.958222    2.580152    3.418884
#
#             ORBR        BIOB       INTB  MOW
# count  84.000000  110.000000  71.000000  0.0
# mean   -0.034174    0.104836   0.108978  NaN
# std     1.086456    1.048582   0.673212  NaN
# min    -2.860720   -1.873265  -1.541242  NaN
# 25%          NaN         NaN        NaN  NaN
# 50%          NaN         NaN        NaN  NaN
# 75%          NaN         NaN        NaN  NaN
# max     4.062620    3.629566   1.549458  NaN
#
# [8 rows x 111 columns]

# %%
#This is fucked. 
#test = test.reindex_axis(sorted(test.count(), reverse=True), axis=1)
test
# Out:
#       1057  1033  1033  1032  1030  1018  1017  1017  1013  1009  ...   110   \
# 5068   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1157   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2277   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2580   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3517   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1258   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3756   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3249   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1389   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3495   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 613    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 5269   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3831   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1831   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1332   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3542   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 842    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2130   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2167   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3819   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 4650   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 422    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 5037   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1647   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3545   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2589   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2581   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1008   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1014   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2935   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...    ...
# 1887   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1133   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2841   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1046   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3931   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2628   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 5313   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2721   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 4790   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3790   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3226   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 5265   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2285   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1416   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2871   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 754    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 737    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 379    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 420    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1743   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2906   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1858   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 4120   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2300   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 1102   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3197   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3372   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 321    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 30     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 4287   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
#
#       110   102   93    91    84    84    71    58    0
# 5068   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1157   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2277   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2580   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3517   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1258   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3756   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3249   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1389   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3495   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 613    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5269   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3831   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1831   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1332   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3542   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 842    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2130   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2167   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3819   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4650   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 422    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5037   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1647   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3545   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2589   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2581   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1008   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1014   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2935   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 1887   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1133   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2841   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1046   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3931   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2628   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5313   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2721   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4790   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3790   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3226   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5265   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2285   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1416   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2871   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 754    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 737    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 379    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 420    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1743   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2906   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1858   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4120   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2300   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1102   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3197   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3372   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 321    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 30     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4287   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1057 rows x 111 columns]

# %%
# poly = PolynomialFeatures(2)
# test = poly.fit_transform(test)
# test = pd.DataFrame(test)
# train= poly.fit_transform(train)
# train= pd.DataFrame()

# %%
#Consider imputing with knn
#Consider removing outliers
#Mean imputation
test = test.fillna(0)
train = train.fillna(0)

# %%
#Write to CSV
train.to_csv("data/train_baseline.csv",index=False)
test.to_csv("data/test_baseline.csv", index=False)
