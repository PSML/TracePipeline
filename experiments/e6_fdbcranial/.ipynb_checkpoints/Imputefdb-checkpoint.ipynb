# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
#Import cranial database 
df = pd.read_csv('../../datasources/fdb/cranial.csv')
#This should shuffle the db.
df = df.sample(frac=1)
#Drop categorical data. We'll focus on measurement data.
del df['DB']
del df['Item']
del df['ID']
del df['ContNum']
del df['FDN']
del df['Pop']
del df['PopSex']
del df['Ethnicity'] #Probably really important.
del df['BirthYear']
del df['Age'] #Probably really important.
del df['Comments']

rows, cols = df.shape 
print("Starting with", rows, "individuals and", cols, "features.")
# Out:
# Starting with 5342 individuals and 111 features.

# %%
#Consider our target col, Sex.
print("Unique entries.")
df['Sex'].value_counts(dropna=False)
# Out:
# Unique entries.
# M      3187
# F      2095
# N        58
# NaN       2
# Name: Sex, dtype: int64

# %%
#Clean N and Nan entries
df = df[~(df.Sex.str.contains("N") == True)]
df = df.dropna(subset = ['Sex'])
#Move from object to float
df['Sex'] = df['Sex'].map({'M':1.0, 'F':0.})
df.describe()
# Out:
#                Sex          GOL          NOL          BNL          BBH  \
# count  5282.000000  5200.000000  4396.000000  5177.000000  5182.000000
# mean      0.603370   180.397500   177.689945   100.143906   133.846584
# std       0.489244     8.838111     8.238570     5.764435     7.336864
# min       0.000000   131.000000   150.000000    79.000000   107.000000
# 25%       0.000000   174.000000   172.000000    96.000000   129.000000
# 50%       1.000000   180.000000   178.000000   100.000000   134.000000
# 75%       1.000000   187.000000   183.000000   104.000000   139.000000
# max       1.000000   211.000000   207.000000   120.000000   157.000000
#
#                XCB          XFB          WFB          ZYB          AUB ...   \
# count  5196.000000  4395.000000  2622.000000  5096.000000  5106.000000 ...
# mean    137.568129   114.752673    94.898932   129.449372   120.855660 ...
# std       6.811824     6.477442     4.952665     7.313785     6.763771 ...
# min     116.000000    93.000000    79.000000    90.000000    98.000000 ...
# 25%     133.000000   110.000000    92.000000   124.000000   116.000000 ...
# 50%     137.000000   115.000000    95.000000   129.000000   121.000000 ...
# 75%     142.000000   119.000000    98.000000   134.000000   125.000000 ...
# max     167.000000   145.000000   119.000000   158.000000   154.000000 ...
#
#               MAN        BABR        BANA        BAPR         UFHT  \
# count  518.000000  636.000000  607.000000  574.000000  2115.000000
# mean   124.990347  136.886792  101.494234   97.031359    70.201891
# std      7.455211    6.889893    5.523686    6.481473     4.934519
# min     90.000000   84.000000   85.000000   73.000000    47.000000
# 25%    120.250000  133.000000   98.000000   93.000000    67.000000
# 50%    125.000000  137.000000  101.000000   97.000000    70.000000
# 75%    130.000000  142.000000  105.000000  101.000000    74.000000
# max    147.000000  156.000000  130.000000  116.000000    91.000000
#
#               UFBR        ORBR        BIOB        INTB  MOW
# count  1605.000000  453.000000  604.000000  413.000000    0
# mean    103.535826   41.008830   96.253311   20.552058  NaN
# std       4.827782    2.493338    4.400408    3.388348  NaN
# min      87.000000   34.000000   81.000000    0.000000  NaN
# 25%     100.000000   39.000000   93.000000   19.000000  NaN
# 50%     104.000000   41.000000   96.000000   21.000000  NaN
# 75%     107.000000   42.000000   99.000000   22.000000  NaN
# max     122.000000   51.000000  112.000000   29.000000  NaN
#
# [8 rows x 111 columns]

# %%
#Split into data and labels.
X = df.drop(['Sex'], axis=1)
y = df[['Sex']]

# %%
#Split train test
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2)

# %%
X_train.isnull().sum().sum()
# Out:
# 167370

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4225, 110), (1057, 110), (4225, 1), (1057, 1))

# %%
#Standardize df
X_train_mean = X_train.mean()
X_train_std = X_train.std()
X_train = (X_train - X_train_mean) / (X_train_std)
#Intentionally using train stats for test. 
X_test = ( X_test - X_train_mean) / (X_train_std)
X_train.describe()
# Out:
#                 GOL           NOL           BNL           BBH           XCB  \
# count  4.158000e+03  3.509000e+03  4.139000e+03  4.143000e+03  4.151000e+03
# mean  -1.500697e-15 -2.815898e-17 -8.157551e-16 -1.668416e-15  1.738262e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -5.609313e+00 -3.370850e+00 -3.658526e+00 -3.641810e+00 -3.193693e+00
# 25%   -7.276585e-01 -6.947888e-01 -7.119141e-01 -6.548632e-01 -6.778768e-01
# 50%   -4.649741e-02  3.504622e-02 -1.859352e-02  2.398838e-02 -8.592001e-02
# 75%    7.481905e-01  6.432421e-01  6.747270e-01  7.028399e-01  6.540259e-01
# max    3.359308e+00  3.562582e+00  3.448009e+00  3.146705e+00  4.353756e+00
#
#                 XFB           WFB           ZYB           AUB           ASB  \
# count  3.505000e+03  2.128000e+03  4.072000e+03  4.082000e+03  3.507000e+03
# mean  -4.518814e-16  4.450283e-16 -1.029247e-16  4.664460e-16 -5.652419e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.240516e+00 -3.203637e+00 -5.381432e+00 -3.367429e+00 -3.389746e+00
# 25%   -7.534743e-01 -7.794786e-01 -7.377361e-01 -7.120253e-01 -7.323920e-01
# 50%    2.372624e-02  2.857424e-02 -5.483967e-02  2.558694e-02 -6.805350e-02
# 75%    6.454867e-01  6.346139e-01  6.280568e-01  6.156767e-01  5.962850e-01
# max    3.598849e+00  4.876891e+00  3.905960e+00  4.893828e+00  3.585808e+00
#
#       ...            MAN          BABR          BANA          BAPR  \
# count ...   4.220000e+02  5.080000e+02  4.860000e+02  4.580000e+02
# mean  ...  -1.787012e-16 -1.687626e-15  1.971445e-16 -8.067297e-16
# std   ...   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   ...  -4.910596e+00 -7.679929e+00 -2.951475e+00 -3.666991e+00
# 25%   ...  -6.170245e-01 -5.898874e-01 -6.292559e-01 -6.222451e-01
# 50%   ...  -6.301526e-02 -1.110845e-02 -9.335922e-02 -1.329583e-02
# 75%   ...   6.294962e-01  7.123652e-01  6.211696e-01  5.956534e-01
# max   ...   2.984035e+00  2.738091e+00  5.086975e+00  2.879213e+00
#
#                UFHT          UFBR          ORBR          BIOB          INTB  \
# count  1.713000e+03  1.306000e+03  3.590000e+02  4.810000e+02  3.370000e+02
# mean   7.343156e-16  1.620705e-16 -1.564827e-16  5.895896e-17  1.640626e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.521536e+00 -3.039650e+00 -2.895143e+00 -3.518924e+00 -6.595017e+00
# 25%   -6.427020e-01 -7.356552e-01 -7.817710e-01 -7.308350e-01 -5.111827e-01
# 50%   -2.580891e-02 -2.566053e-03  6.357776e-02 -3.381259e-02  1.292209e-01
# 75%    5.910842e-01  7.305231e-01  4.862522e-01  6.632098e-01  4.494227e-01
# max    4.292443e+00  3.034518e+00  3.867647e+00  3.683640e+00  2.690835e+00
#
#        MOW
# count    0
# mean   NaN
# std    NaN
# min    NaN
# 25%    NaN
# 50%    NaN
# 75%    NaN
# max    NaN
#
# [8 rows x 110 columns]

# %%
#The imputer. I haven't looked closely at this algo. 
#Should probably be doing this after standardization because of scaling concerns.
from fancyimpute import KNN
X_train_filled = pd.DataFrame(KNN(k=3).complete(X_train))
X_test_filled = pd.DataFrame(KNN(k=3).complete(X_test))
# Out:
# Computing pairwise distances between 4225 samples
# Computing distances for sample #1/4225, elapsed time: 1.996
# Computing distances for sample #101/4225, elapsed time: 2.242
# No samples have sufficient overlap with sample 123
# Computing distances for sample #201/4225, elapsed time: 2.538
# Computing distances for sample #301/4225, elapsed time: 2.920
# Computing distances for sample #401/4225, elapsed time: 3.197
# Computing distances for sample #501/4225, elapsed time: 3.555
# Computing distances for sample #601/4225, elapsed time: 3.957
# Computing distances for sample #701/4225, elapsed time: 4.347
# Computing distances for sample #801/4225, elapsed time: 4.761
# Computing distances for sample #901/4225, elapsed time: 5.102
# Computing distances for sample #1001/4225, elapsed time: 5.398
# Computing distances for sample #1101/4225, elapsed time: 5.813
# Computing distances for sample #1201/4225, elapsed time: 6.166
# No samples have sufficient overlap with sample 1295
# Computing distances for sample #1301/4225, elapsed time: 6.401
# Computing distances for sample #1401/4225, elapsed time: 6.635
# Computing distances for sample #1501/4225, elapsed time: 6.919
# No samples have sufficient overlap with sample 1502
# Computing distances for sample #1601/4225, elapsed time: 7.163
# Computing distances for sample #1701/4225, elapsed time: 7.404
# Computing distances for sample #1801/4225, elapsed time: 7.640
# Computing distances for sample #1901/4225, elapsed time: 7.876
# No samples have sufficient overlap with sample 1914
# Computing distances for sample #2001/4225, elapsed time: 8.106
# No samples have sufficient overlap with sample 2038
# Computing distances for sample #2101/4225, elapsed time: 8.363
# No samples have sufficient overlap with sample 2190
# Computing distances for sample #2201/4225, elapsed time: 8.604
# No samples have sufficient overlap with sample 2224
# Computing distances for sample #2301/4225, elapsed time: 8.852
# Computing distances for sample #2401/4225, elapsed time: 9.089
# Computing distances for sample #2501/4225, elapsed time: 9.326
# Computing distances for sample #2601/4225, elapsed time: 9.561
# No samples have sufficient overlap with sample 2617
# Computing distances for sample #2701/4225, elapsed time: 9.812
# Computing distances for sample #2801/4225, elapsed time: 10.046
# No samples have sufficient overlap with sample 2842
# Computing distances for sample #2901/4225, elapsed time: 10.301
# Computing distances for sample #3001/4225, elapsed time: 10.538
# Computing distances for sample #3101/4225, elapsed time: 10.770
# Computing distances for sample #3201/4225, elapsed time: 11.002
# Computing distances for sample #3301/4225, elapsed time: 11.231
# No samples have sufficient overlap with sample 3358
# Computing distances for sample #3401/4225, elapsed time: 11.478
# No samples have sufficient overlap with sample 3467
# Computing distances for sample #3501/4225, elapsed time: 11.729
# No samples have sufficient overlap with sample 3504
# No samples have sufficient overlap with sample 3513
# No samples have sufficient overlap with sample 3515
# Computing distances for sample #3601/4225, elapsed time: 11.955
# No samples have sufficient overlap with sample 3671
# Computing distances for sample #3701/4225, elapsed time: 12.203
# No samples have sufficient overlap with sample 3769
# Computing distances for sample #3801/4225, elapsed time: 12.450
# Computing distances for sample #3901/4225, elapsed time: 12.682
# Computing distances for sample #4001/4225, elapsed time: 12.915
# Computing distances for sample #4101/4225, elapsed time: 13.153
# Computing distances for sample #4201/4225, elapsed time: 13.382
# Imputing row 1/4225 with 63 missing columns, elapsed time: 14.648
# Imputing row 101/4225 with 40 missing columns, elapsed time: 14.766
# Imputing row 201/4225 with 29 missing columns, elapsed time: 14.879
# Imputing row 301/4225 with 26 missing columns, elapsed time: 14.999
# Imputing row 401/4225 with 19 missing columns, elapsed time: 15.115
# Imputing row 501/4225 with 28 missing columns, elapsed time: 15.241
# Imputing row 601/4225 with 19 missing columns, elapsed time: 15.352
# Imputing row 701/4225 with 19 missing columns, elapsed time: 15.466
# Imputing row 801/4225 with 22 missing columns, elapsed time: 15.570
# Imputing row 901/4225 with 29 missing columns, elapsed time: 15.704
# Imputing row 1001/4225 with 29 missing columns, elapsed time: 15.821
# Imputing row 1101/4225 with 19 missing columns, elapsed time: 15.945
# Imputing row 1201/4225 with 29 missing columns, elapsed time: 16.063
# Imputing row 1301/4225 with 29 missing columns, elapsed time: 16.180
# Imputing row 1401/4225 with 74 missing columns, elapsed time: 16.294
# Imputing row 1501/4225 with 26 missing columns, elapsed time: 16.417
# Imputing row 1601/4225 with 29 missing columns, elapsed time: 16.542
# Imputing row 1701/4225 with 20 missing columns, elapsed time: 16.665
# Imputing row 1801/4225 with 29 missing columns, elapsed time: 16.779
# Imputing row 1901/4225 with 29 missing columns, elapsed time: 16.893
# Imputing row 2001/4225 with 30 missing columns, elapsed time: 17.013
# Imputing row 2101/4225 with 19 missing columns, elapsed time: 17.141
# Imputing row 2201/4225 with 29 missing columns, elapsed time: 17.260
# Imputing row 2301/4225 with 82 missing columns, elapsed time: 17.371
# Imputing row 2401/4225 with 29 missing columns, elapsed time: 17.488
# Imputing row 2501/4225 with 29 missing columns, elapsed time: 17.600
# Imputing row 2601/4225 with 40 missing columns, elapsed time: 17.721
# Imputing row 2701/4225 with 40 missing columns, elapsed time: 17.831
# Imputing row 2801/4225 with 12 missing columns, elapsed time: 17.954
# Imputing row 2901/4225 with 29 missing columns, elapsed time: 18.078
# Imputing row 3001/4225 with 19 missing columns, elapsed time: 18.215
# Imputing row 3101/4225 with 40 missing columns, elapsed time: 18.318
# Imputing row 3201/4225 with 29 missing columns, elapsed time: 18.416
# Imputing row 3301/4225 with 40 missing columns, elapsed time: 18.532
# Imputing row 3401/4225 with 29 missing columns, elapsed time: 18.642
# Imputing row 3501/4225 with 63 missing columns, elapsed time: 18.757
# Imputing row 3601/4225 with 29 missing columns, elapsed time: 18.874
# Imputing row 3701/4225 with 75 missing columns, elapsed time: 18.994
# Imputing row 3801/4225 with 26 missing columns, elapsed time: 19.107
# Imputing row 3901/4225 with 29 missing columns, elapsed time: 19.235
# Imputing row 4001/4225 with 89 missing columns, elapsed time: 19.364
# Imputing row 4101/4225 with 29 missing columns, elapsed time: 19.493
# Imputing row 4201/4225 with 81 missing columns, elapsed time: 19.600
# [KNN] Warning: 11594/464750 still missing after imputation, replacing with 0
# Computing pairwise distances between 1057 samples
# Computing distances for sample #1/1057, elapsed time: 0.092
# Computing distances for sample #101/1057, elapsed time: 0.147
# Computing distances for sample #201/1057, elapsed time: 0.205
# Computing distances for sample #301/1057, elapsed time: 0.261
# Computing distances for sample #401/1057, elapsed time: 0.316
# No samples have sufficient overlap with sample 426
# Computing distances for sample #501/1057, elapsed time: 0.373
# No samples have sufficient overlap with sample 588
# Computing distances for sample #601/1057, elapsed time: 0.429
# Computing distances for sample #701/1057, elapsed time: 0.485
# Computing distances for sample #801/1057, elapsed time: 0.541
# Computing distances for sample #901/1057, elapsed time: 0.597
# Computing distances for sample #1001/1057, elapsed time: 0.653
# Imputing row 1/1057 with 40 missing columns, elapsed time: 0.756
# Imputing row 101/1057 with 29 missing columns, elapsed time: 0.810
# Imputing row 201/1057 with 89 missing columns, elapsed time: 0.870
# Imputing row 301/1057 with 87 missing columns, elapsed time: 0.930
# Imputing row 401/1057 with 85 missing columns, elapsed time: 0.988
# Imputing row 501/1057 with 26 missing columns, elapsed time: 1.051
# Imputing row 601/1057 with 40 missing columns, elapsed time: 1.105
# Imputing row 701/1057 with 29 missing columns, elapsed time: 1.163
# Imputing row 801/1057 with 29 missing columns, elapsed time: 1.222
# Imputing row 901/1057 with 40 missing columns, elapsed time: 1.277
# Imputing row 1001/1057 with 85 missing columns, elapsed time: 1.335
# [KNN] Warning: 1525/116270 still missing after imputation, replacing with 0

# %%
#Num zero entries
(X_train_filled == 0).astype(int).sum().sum(),(X_test_filled == 0).astype(int).sum().sum()
# Out:
# (11594, 1525)

# %%
#Impute zeros with mean.
from sklearn.preprocessing import Imputer
imp = Imputer(missing_values=0, strategy='mean', axis=0)
imp.fit(X_train_filled)
X_train_filled = pd.DataFrame(imp.transform(X_train_filled))
imp.fit(X_test_filled)
X_test_filled = pd.DataFrame(imp.transform(X_test_filled))

# %%
#No zero values
(X_train_filled == 0).astype(int).sum().sum(), (X_test_filled == 0).astype(int).sum().sum()
# Out:
# (0, 0)

# %%
X_test_filled.describe()
# Out:
#                0            1            2            3            4    \
# count  1057.000000  1057.000000  1057.000000  1057.000000  1057.000000
# mean     -0.006153     0.013342     0.034701     0.017076    -0.009161
# std       1.012210     0.989433     0.989273     0.974934     1.034898
# min      -2.998195    -3.127572    -2.445215    -2.962958    -2.897715
# 25%      -0.727658    -0.669987    -0.711914    -0.654863    -0.677877
# 50%      -0.046497     0.035046    -0.018594     0.023988    -0.085920
# 75%       0.748190     0.649168     0.674727     0.702840     0.654026
# max       3.472835     3.562582     2.928019     2.875165     4.353756
#
#                5            6            7            8            9    \
# count  1057.000000  1057.000000  1057.000000  1057.000000  1057.000000
# mean     -0.038032     0.044000     0.022003     0.020797     0.052839
# std       0.987174     0.898057     0.988732     0.979939     1.019429
# min      -3.395956    -3.203637    -3.196163    -3.072384    -2.891492
# 25%      -0.753474    -0.577465    -0.601157    -0.712025    -0.608701
# 50%      -0.075509     0.028574     0.081740     0.025587     0.098031
# 75%       0.645487     0.634614     0.764636     0.763199     0.695513
# max       4.686930     3.462799     3.359643     3.566126     2.921470
#
#           ...               99           100          101          102  \
# count     ...       1057.000000  1057.000000  1057.000000  1057.000000
# mean      ...          0.072520    -0.179931    -0.342278    -0.122041
# std       ...          0.490626     0.666695     0.804553     0.705637
# min       ...         -2.162979    -3.110066    -2.470919    -1.879681
# 25%       ...         -0.222919    -0.582073    -1.010467    -0.602577
# 50%       ...          0.022333    -0.091471    -0.300498    -0.261497
# 75%       ...          0.346607     0.305258     0.278281     0.266096
# max       ...          3.333594     2.291524     2.448702     2.764756
#
#                103          104          105          106          107  \
# count  1057.000000  1057.000000  1057.000000  1057.000000  1057.000000
# mean      0.078828    -0.065413     0.008699     0.264334     0.055314
# std       0.689426     0.888212     0.869841     0.833914     0.819133
# min      -2.601330    -4.755322    -3.458558    -1.627120    -1.892539
# 25%      -0.390509    -0.642702    -0.526201    -0.318731    -0.462775
# 50%       0.116412    -0.025809    -0.054903     0.175490    -0.001859
# 75%       0.529137     0.490061     0.521069     0.634131     0.521139
# max       2.422501     3.264287     3.872334     4.290322     3.683640
#
#                108
# count  1057.000000
# mean      0.064749
# std       0.771703
# min      -6.595017
# 25%      -0.340454
# 50%       0.185241
# 75%       0.580868
# max       1.730230
#
# [8 rows x 109 columns]

# %%
# #Standardize
# from sklearn import preprocessing
# X_train_filled = pd.DataFrame(preprocessing.scale(X_train_filled))
# X_test_filled = pd.DataFrame(preprocessing.scale(X_test_filled))

# %%
X_test_filled.describe()
# Out:
#                0            1            2            3            4    \
# count  1057.000000  1057.000000  1057.000000  1057.000000  1057.000000
# mean     -0.006153     0.013342     0.034701     0.017076    -0.009161
# std       1.012210     0.989433     0.989273     0.974934     1.034898
# min      -2.998195    -3.127572    -2.445215    -2.962958    -2.897715
# 25%      -0.727658    -0.669987    -0.711914    -0.654863    -0.677877
# 50%      -0.046497     0.035046    -0.018594     0.023988    -0.085920
# 75%       0.748190     0.649168     0.674727     0.702840     0.654026
# max       3.472835     3.562582     2.928019     2.875165     4.353756
#
#                5            6            7            8            9    \
# count  1057.000000  1057.000000  1057.000000  1057.000000  1057.000000
# mean     -0.038032     0.044000     0.022003     0.020797     0.052839
# std       0.987174     0.898057     0.988732     0.979939     1.019429
# min      -3.395956    -3.203637    -3.196163    -3.072384    -2.891492
# 25%      -0.753474    -0.577465    -0.601157    -0.712025    -0.608701
# 50%      -0.075509     0.028574     0.081740     0.025587     0.098031
# 75%       0.645487     0.634614     0.764636     0.763199     0.695513
# max       4.686930     3.462799     3.359643     3.566126     2.921470
#
#           ...               99           100          101          102  \
# count     ...       1057.000000  1057.000000  1057.000000  1057.000000
# mean      ...          0.072520    -0.179931    -0.342278    -0.122041
# std       ...          0.490626     0.666695     0.804553     0.705637
# min       ...         -2.162979    -3.110066    -2.470919    -1.879681
# 25%       ...         -0.222919    -0.582073    -1.010467    -0.602577
# 50%       ...          0.022333    -0.091471    -0.300498    -0.261497
# 75%       ...          0.346607     0.305258     0.278281     0.266096
# max       ...          3.333594     2.291524     2.448702     2.764756
#
#                103          104          105          106          107  \
# count  1057.000000  1057.000000  1057.000000  1057.000000  1057.000000
# mean      0.078828    -0.065413     0.008699     0.264334     0.055314
# std       0.689426     0.888212     0.869841     0.833914     0.819133
# min      -2.601330    -4.755322    -3.458558    -1.627120    -1.892539
# 25%      -0.390509    -0.642702    -0.526201    -0.318731    -0.462775
# 50%       0.116412    -0.025809    -0.054903     0.175490    -0.001859
# 75%       0.529137     0.490061     0.521069     0.634131     0.521139
# max       2.422501     3.264287     3.872334     4.290322     3.683640
#
#                108
# count  1057.000000
# mean      0.064749
# std       0.771703
# min      -6.595017
# 25%      -0.340454
# 50%       0.185241
# 75%       0.580868
# max       1.730230
#
# [8 rows x 109 columns]

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit( X_train_filled, np.ravel(y_train) )
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
from sklearn import cross_validation
#scores = cross_validation.cross_val_score(clf, X_test_preprocessed, np.ravel( (y_test+1)/2), cv=5)
clf.score(X_test_filled, np.ravel(y_test))
# Out:
# 0.88741721854304634

# %%
p=clf.predict(X_test_filled)
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_test, p), annot=True)
