# %%
# %matplotlib inline
import json
import matplotlib.pyplot as plt
from numpy import array, zeros
from scipy.misc import imread
from glob import glob

# d_dir = '/Users/tu/Downloads/neurofinder.04.00/images/*.tiff'

# data_dir = '../../datasources/neurofinder.01.00/'

# load the images
files = sorted(glob(/Users/tu/Downloads/neurofinder.04.00/images/*.tiff))
imgs = array([imread(f) for f in files])
dims = imgs.shape[1:]

# load the regions (training data only)
with open('/Users/tu/Downloads/neurofinder.04.00/regions/regions.json') as f:
    regions = json.load(f)
# Out:
#   File "<ipython-input-116-34091bed76a6>", line 13
#     files = sorted(glob(/Users/tu/Downloads/neurofinder.04.00/images/*.tiff))
#                         ^
# SyntaxError: invalid syntax

# %%
#Imgs are 512x512
a = np.unique(imgs[0], return_counts=True)
plt.scatter(a[0],a[1])

a[1]
# Out:
# array([2343,   59,   67, ...,    2,    1,  728])

# %%
x=[]
y=[]
for j in regions[0:]:
    for i in j['coordinates']:
        x.append(i[0])
        y.append(i[1])
plt.scatter(x, y)
plt.show()

# %%
def tomask(coords):
    mask = zeros(dims)
    mask[zip(*coords)] = 1
    return mask

# %%
imshow(np.asarray(imgs[0]))

# %%
masks = array([tomask(s['coordinates']) for s in regions])
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:3: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-39ae87107e96> in <module>()
# ----> 1 masks = array([tomask(s['coordinates']) for s in regions])
#
# <ipython-input-42-39ae87107e96> in <listcomp>(.0)
# ----> 1 masks = array([tomask(s['coordinates']) for s in regions])
#
# <ipython-input-41-fa2f63da91cb> in tomask(coords)
#       1 def tomask(coords):
#       2     mask = zeros(dims)
# ----> 3     mask[zip(*coords)] = 1
#       4     return mask
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
#for s in regions:
#    print(s['coordinates'])
coords = regions[0]['coordinates']
m = zeros(dims)
#list(zip(*coords))
#coords

# %%
#Show an example image
from PIL import Image
a = np.uint8(imgs[0])
Image.fromarray(a)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x10C50F978>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2163             typekey = (1, 1) + shape[2:], arr['typestr']
# -> 2164             mode, rawmode = _fromarray_typemap[typekey]
#    2165         except KeyError:
#
# KeyError: ((1, 1), '<u2')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-fe9c15a39079> in <module>()
#       5 data = np.zeros((h, w, 3), dtype=np.uint8)
#       6 data[256, 256] = [255, 0, 0]
# ----> 7 img = Image.fromarray(imgs[0])
#       8 #img.save('my.png')
#       9 img.show()
#
# /usr/local/lib/python3.5/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2165         except KeyError:
#    2166             # print typekey
# ...

# %%
from matplotlib.pyplot import imshow
#pil_im = Image.open('../../datasources/neurofinder.01.00/images/image00000.tiff', 'r')
imshow(np.asarray(imgs[0]))

# %%
imshow(np.asarray(imgs[10]))

# %%
imshow(np.asarray(imgs[20]))

# %%
imshow(np.asarray(imgs[500]))

# %%
imshow(np.asarray(imgs[999]))

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2163             typekey = (1, 1) + shape[2:], arr['typestr']
# -> 2164             mode, rawmode = _fromarray_typemap[typekey]
#    2165         except KeyError:
#
# KeyError: ((1, 1), '<u2')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-62eff8e65bf2> in <module>()
#      10
#      11 for ima in imgs:
# ---> 12     display_img_array(ima)
#
# <ipython-input-81-62eff8e65bf2> in display_img_array(ima)
#       4
#       5 def display_img_array(ima):
# ----> 6     im = PIL.Image.fromarray(ima)
#       7     bio = BytesIO()
#       8     im.save(bio)
#
# /usr/local/lib/python3.5/site-packages/PIL/Image.py in fromarray(obj, mode)
# ...

# %%
hmpf = np.ones([4,4])
hmpf[2][1] = 0
imagelist = [ hmpf*i*255./19. for i in range(20) ]

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
fig = plt.figure() # make figure

# make axesimage object
# the vmin and vmax here are very important to get the color map correct
im = plt.imshow(imagelist[0], cmap=plt.get_cmap('jet'), vmin=0, vmax=255)

# function to update figure
def updatefig(j):
    # set the data in the axesimage object
    im.set_array(imgs[j])
    # return the artists set
    return im,
# kick off the animation
ani = animation.FuncAnimation(fig, updatefig, frames=range(20), 
                              interval=50, blit=True)
plt.show()
