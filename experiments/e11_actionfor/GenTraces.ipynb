# %%
'''An attempt to classify a recursive computation from a for loop implementation 
using only a state trace of the register state of the 6502 processor it's simulated on.'''
import random
import numpy as np
import glob
from scipy import misc

# %%
#Parameters
mode = 'act'
trace_dir = 'traces'
image_dir = 'images'

# %%
#Clean up
# !make clean
# Out:
# rm -rf *~ *.o *.map *.img *.lst *.out memcpy.s memcpy backup 'images' *.s traces tmp

# %%
# %%time 
#About 50s

#Number of increments.
num_inc = 10
#Generate some 6502 images
#Avoid rollover of the 8 bit regs by not hitting 256.
#Avoid 0 because gave weird trace.
for start in range(1,255-num_inc):
    # !make START={start} MAX={start+num_inc} IMGDIR={image_dir}
# Out:
# ../../datasources/6502/ext/install/bin/cc65 -D START=1 -D MAX=11 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 1_11forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=1 -D MAX=11 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 1_11recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=2 -D MAX=12 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 2_12forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=2 -D MAX=12 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 2_12recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=3 -D MAX=13 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 3_13forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=3 -D MAX=13 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 3_13recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=4 -D MAX=14 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 4_14forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=4 -D MAX=14 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 4_14recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=5 -D MAX=15 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 5_15forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=5 -D MAX=15 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 5_15recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=6 -D MAX=16 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 6_16forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=6 -D MAX=16 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 6_16recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=7 -D MAX=17 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 7_17forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=7 -D MAX=17 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 7_17recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=8 -D MAX=18 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 8_18forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=8 -D MAX=18 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 8_18recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=9 -D MAX=19 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 9_19forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=9 -D MAX=19 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 9_19recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=10 -D MAX=20 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 10_20forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=10 -D MAX=20 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 10_20recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=11 -D MAX=21 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 11_21forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=11 -D MAX=21 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 11_21recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=12 -D MAX=22 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 12_22forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=12 -D MAX=22 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 12_22recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=13 -D MAX=23 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 13_23forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=13 -D MAX=23 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 13_23recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=14 -D MAX=24 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 14_24forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=14 -D MAX=24 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 14_24recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=15 -D MAX=25 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 15_25forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=15 -D MAX=25 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 15_25recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=16 -D MAX=26 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 16_26forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=16 -D MAX=26 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 16_26recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=17 -D MAX=27 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 17_27forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=17 -D MAX=27 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 17_27recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=18 -D MAX=28 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 18_28forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=18 -D MAX=28 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 18_28recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=19 -D MAX=29 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 19_29forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=19 -D MAX=29 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 19_29recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=20 -D MAX=30 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 20_30forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=20 -D MAX=30 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 20_30recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=21 -D MAX=31 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 21_31forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=21 -D MAX=31 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 21_31recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=22 -D MAX=32 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 22_32forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=22 -D MAX=32 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 22_32recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=23 -D MAX=33 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 23_33forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=23 -D MAX=33 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 23_33recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=24 -D MAX=34 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 24_34forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=24 -D MAX=34 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 24_34recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=25 -D MAX=35 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 25_35forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=25 -D MAX=35 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 25_35recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=26 -D MAX=36 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 26_36forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=26 -D MAX=36 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 26_36recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=27 -D MAX=37 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 27_37forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=27 -D MAX=37 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 27_37recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=28 -D MAX=38 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 28_38forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=28 -D MAX=38 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 28_38recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=29 -D MAX=39 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 29_39forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=29 -D MAX=39 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 29_39recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=30 -D MAX=40 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 30_40forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=30 -D MAX=40 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 30_40recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=31 -D MAX=41 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 31_41forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=31 -D MAX=41 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 31_41recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=32 -D MAX=42 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 32_42forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=32 -D MAX=42 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 32_42recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=33 -D MAX=43 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 33_43forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=33 -D MAX=43 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 33_43recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=34 -D MAX=44 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 34_44forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=34 -D MAX=44 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 34_44recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=35 -D MAX=45 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 35_45forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=35 -D MAX=45 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 35_45recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=36 -D MAX=46 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 36_46forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=36 -D MAX=46 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 36_46recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=37 -D MAX=47 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 37_47forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=37 -D MAX=47 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 37_47recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=38 -D MAX=48 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 38_48forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=38 -D MAX=48 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 38_48recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=39 -D MAX=49 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 39_49forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=39 -D MAX=49 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 39_49recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=40 -D MAX=50 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 40_50forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=40 -D MAX=50 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 40_50recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=41 -D MAX=51 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 41_51forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=41 -D MAX=51 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 41_51recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=42 -D MAX=52 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 42_52forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=42 -D MAX=52 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 42_52recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=43 -D MAX=53 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 43_53forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=43 -D MAX=53 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 43_53recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=44 -D MAX=54 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 44_54forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=44 -D MAX=54 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 44_54recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=45 -D MAX=55 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 45_55forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=45 -D MAX=55 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 45_55recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=46 -D MAX=56 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 46_56forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=46 -D MAX=56 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ...
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=230 -D MAX=240 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 230_240forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=230 -D MAX=240 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 230_240recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=231 -D MAX=241 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 231_241forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=231 -D MAX=241 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 231_241recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=232 -D MAX=242 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 232_242forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=232 -D MAX=242 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 232_242recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=233 -D MAX=243 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 233_243forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=233 -D MAX=243 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 233_243recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=234 -D MAX=244 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 234_244forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=234 -D MAX=244 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 234_244recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=235 -D MAX=245 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 235_245forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=235 -D MAX=245 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 235_245recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=236 -D MAX=246 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 236_246forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=236 -D MAX=246 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 236_246recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=237 -D MAX=247 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 237_247forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=237 -D MAX=247 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 237_247recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=238 -D MAX=248 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 238_248forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=238 -D MAX=248 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 238_248recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=239 -D MAX=249 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 239_249forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=239 -D MAX=249 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 239_249recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=240 -D MAX=250 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 240_250forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=240 -D MAX=250 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 240_250recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=241 -D MAX=251 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 241_251forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=241 -D MAX=251 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 241_251recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=242 -D MAX=252 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 242_252forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=242 -D MAX=252 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 242_252recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=243 -D MAX=253 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 243_253forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=243 -D MAX=253 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 243_253recCount.img
# mv *.img images
# rm recCount.o forCount.o
# ../../datasources/6502/ext/install/bin/cc65 -D START=244 -D MAX=254 -D__6502__ -t none -O -Oi --cpu 6502 forCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 forCount.s -l forCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o forCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  forCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m forCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv forCount 244_254forCount.img
# mv *.img images
# ../../datasources/6502/ext/install/bin/cc65 -D START=244 -D MAX=254 -D__6502__ -t none -O -Oi --cpu 6502 recCount.c
# ../../datasources/6502/ext/install/bin/ca65 --cpu 6502 recCount.s -l recCount.lst
# ../../datasources/6502/ext/install/bin/ld65 -o recCount -C ../../datasources/6502/apps/cc/apps/bu6502.cfg  recCount.o ../../datasources/6502/apps/cc/apps/bu6502.lib   -m recCount.map
# [ -d 'backup' ] || mkdir backup
# mv *.lst *.map *.s backup
# [ -d images ] || mkdir images
# mv recCount 244_254recCount.img
# mv *.img images
# rm recCount.o forCount.o
# CPU times: user 850 ms, sys: 870 ms, total: 1.72 s
# Wall time: 50.3 s

# %%
# %%time
#Run images through 6520 simulator to generate traces.
# !mkdir -p {trace_dir}
traces = !ls {image_dir}
for t in traces:
    # !../../datasources/6502/6502 -t {mode} -o {trace_dir}/{t}.trc {image_dir}/{t} /dev/null 2> /dev/null
# Out:
# CPU times: user 587 ms, sys: 1.22 s, total: 1.8 s
# Wall time: 1min 2s
